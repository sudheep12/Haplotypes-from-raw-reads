# %%
from Bio import SeqIO
import os
import glob
import re

# %%
dir1 = "~/raw_reads_After_DescripterChange"

forward_read_mix1= "forward_read/HIV1_variant_MIX1_S2_HIV1_modDes_R1.fastq"
reverse_read_mix1= "reverse_read/HIV1_variant_MIX1_S2_HIV1_modDes_R2.fastq"

# %%
in_1_mix1= os.path.join(dir1, "MIX1_S2", forward_read_mix1)
in_2_mix1= os.path.join(dir1, "MIX1_S2", reverse_read_mix1)
    
qtrim_R1_outfile= ["qtrim_20","qtrim_25","qtrim_30"]
qtrim_R2_outfile= ["qtrim_20","qtrim_25","qtrim_30"]
j=0
for i in qtrim_R1_outfile:
    out_file = os.path.abspath(os.path.join("bbduk_cliquesnv", "MIX1_S2", i+ 'R1_'+'.fastq'))
    out_file1 = os.path.abspath(os.path.join("bbduk_cliquesnv","MIX1_S2" , i+ 'R2_' +'.fastq'))
    qtrim_values= [20,25,30]
    qtrim_value= qtrim_values[j]
    print(in_1_mix1, out_file)
    # !/alina-data2/sai/BBduk/bbmap/bbduk.sh in1=$in_1_mix1 in2=$in_2_mix1 out1=$out_file out2=$out_file1 maq=$qtrim_value
    j+=1
# k=0    
# for i in qtrim_R2_outfile:
#     out_file1 = os.path.abspath(os.path.join("bbduk_cliquesnv","MIX1_S2" , i+'.fastq'))
#     qtrim_values1= [20,25,30]
#     qtrim_value1= qtrim_values1[k]
#     print(in_2_mix1, out_file1)
#     !/alina-data2/sai/BBduk/bbmap/bbduk.sh in=$in_2_mix1 out=$out_file1 maq=$qtrim_value1
#     k+=1
# Out:
# ~/raw_reads_After_DescripterChange/MIX1_S2/forward_read/HIV1_variant_MIX1_S2_HIV1_modDes_R1.fastq /alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX1_S2/qtrim_20R1_.fastq
# java -ea -Xmx286593m -Xms286593m -cp /alina-data2/sai/BBduk/bbmap/current/ jgi.BBDuk in1=~/raw_reads_After_DescripterChange/MIX1_S2/forward_read/HIV1_variant_MIX1_S2_HIV1_modDes_R1.fastq in2=~/raw_reads_After_DescripterChange/MIX1_S2/reverse_read/HIV1_variant_MIX1_S2_HIV1_modDes_R2.fastq out1=/alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX1_S2/qtrim_20R1_.fastq out2=/alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX1_S2/qtrim_20R2_.fastq maq=20
# ...

# %%
dir1 = "~/raw_reads_After_DescripterChange"
in_dir = [ "MIX2/"]
forward_read_mix2= "forward_read/HIV1_variant_MIX2_S3_modDes_R1.fastq"
reverse_read_mix2= "reverse_read/HIV1_variant_MIX2_S3_modDes_R2.fastq"

# %%
in_1_mix2= os.path.join(dir1, "MIX2", forward_read_mix2)
in_2_mix2= os.path.join(dir1, "MIX2", reverse_read_mix2)
    
qtrim_R1_outfile= ["qtrim_20","qtrim_25","qtrim_30"]
qtrim_R2_outfile= ["qtrim_20","qtrim_25","qtrim_30"]
j=0
for i in qtrim_R1_outfile:
    out_file = os.path.abspath(os.path.join("bbduk_cliquesnv", "MIX2", i+ 'R1_'+'.fastq'))
    out_file1 = os.path.abspath(os.path.join("bbduk_cliquesnv", "MIX2", i+ 'R2_'+'.fastq'))
    qtrim_values= [20,25,30]
    qtrim_value= qtrim_values[j]
    print(in_1_mix2, out_file)
    # !/alina-data2/sai/BBduk/bbmap/bbduk.sh in1=$in_1_mix2 in2=$in_2_mix2 out1=$out_file out2=$out_file1 maq=$qtrim_value
    j+=1
# k=0    
# for i in qtrim_R2_outfile:
#     out_file1 = os.path.abspath(os.path.join("bbduk_cliquesnv", "MIX2", i+'.fastq'))
#     qtrim_values1= [20,25,30]
#     qtrim_value1= qtrim_values1[k]
#     print(in_2_mix2, out_file1)
#     !/alina-data2/sai/BBduk/bbmap/bbduk.sh in=$in_2_mix2 out=$out_file1 maq=$qtrim_value1
#     k+=1
# Out:
# ~/raw_reads_After_DescripterChange/MIX2/forward_read/HIV1_variant_MIX2_S3_modDes_R1.fastq /alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX2/qtrim_20R1_.fastq
# java -ea -Xmx285005m -Xms285005m -cp /alina-data2/sai/BBduk/bbmap/current/ jgi.BBDuk in1=~/raw_reads_After_DescripterChange/MIX2/forward_read/HIV1_variant_MIX2_S3_modDes_R1.fastq in2=~/raw_reads_After_DescripterChange/MIX2/reverse_read/HIV1_variant_MIX2_S3_modDes_R2.fastq out1=/alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX2/qtrim_20R1_.fastq out2=/alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX2/qtrim_20R2_.fastq maq=20
# ...

# %%
dir1 = "~/raw_reads_After_DescripterChange"
in_dir = ["MIX3/"]
forward_read_mix3= "forward_read/HIV1_variant_MIX3_S4_modDes_R1.fastq"
reverse_read_mix3= "reverse_read/HIV1_variant_MIX3_S4_modDes_R2.fastq"

# %%
in_1_mix3= os.path.join(dir1, "MIX3", forward_read_mix3)
in_2_mix3= os.path.join(dir1, "MIX3", reverse_read_mix3)
qtrim_R1_outfile= ["qtrim_20","qtrim_25","qtrim_30"]
qtrim_R2_outfile= ["qtrim_20","qtrim_25","qtrim_30"]
j=0
for i in qtrim_R1_outfile:
    out_file = os.path.abspath(os.path.join("bbduk_cliquesnv", "MIX3", i+ 'R1_'+'.fastq'))
    out_file1 = os.path.abspath(os.path.join("bbduk_cliquesnv", "MIX3", i+ 'R2_'+'.fastq'))
    qtrim_values2= [20,25,30]
    qtrim_value2= qtrim_values2[j]
    print(in_1_mix1, out_file)
    # !/alina-data2/sai/BBduk/bbmap/bbduk.sh in1=$in_1_mix3 in2=$in_2_mix3 out1=$out_file out2=$out_file1 maq=$qtrim_value2
    j+=1
# k=0    
# for i in qtrim_R2_outfile:
#     out_file1 = os.path.abspath(os.path.join("bbduk_cliquesnv", "MIX3", i+))
#     qtrim_values= [20,25,30]
#     qtrim_value= qtrim_values[k]
#     print(in_2_mix1, out_file1)
#     !/alina-data2/sai/BBduk/bbmap/bbduk.sh in=$in_2_mix3 out=$out_file1 maq=$qtrim_value
#     k+=1
# Out:
# ~/raw_reads_After_DescripterChange/MIX1_S2/forward_read/HIV1_variant_MIX1_S2_HIV1_modDes_R1.fastq /alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX3/qtrim_20R1_.fastq
# java -ea -Xmx284361m -Xms284361m -cp /alina-data2/sai/BBduk/bbmap/current/ jgi.BBDuk in1=~/raw_reads_After_DescripterChange/MIX3/forward_read/HIV1_variant_MIX3_S4_modDes_R1.fastq in2=~/raw_reads_After_DescripterChange/MIX3/reverse_read/HIV1_variant_MIX3_S4_modDes_R2.fastq out1=/alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX3/qtrim_20R1_.fastq out2=/alina-data2/sai/ipython_working_dir/bbduk_cliquesnv/MIX3/qtrim_20R2_.fastq maq=20
# ...
