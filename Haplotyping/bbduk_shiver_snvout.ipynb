# %%
import os

# %%
dir1= "shiver_working_dir"
mixtures_list= ["MIX1_S2","MIX2","MIX3"]
qtrim_dir= ["qtrim_20","qtrim_25","qtrim_30"]

# %%
for i in mixtures_list:
    infile = os.path.join(dir1, i)
    for j in qtrim_dir:
        infile1= (os.path.join("/alina-data2", "sai",infile, j,"SID.sam"))
        outpath= ["t_10_tf_0.034", "t_50_tf_0.005", "t_100_tf_0.01", "t_200_tf_0.02", "t_500_tf_0.05"]
        clique_out = os.path.abspath(os.path.join("bbduk_shiver_snvOut",i,j ))
#         print(infile1, '', clique_out)
        k=0
        for cd in outpath:
            t = ['10', '50', '100', '200', '500']
            tf= ['0.00034','0.005', '0.01', '0.02', '0.05']
            t_value = t[k]
            tf_value = tf[k]
            outsnv= os.path.abspath(os.path.join(clique_out, cd))
            print(infile1, outsnv)
            # !java -jar /home/code/cliquesnv/CliqueSNV/clique-snv.jar -m snv-illumina -in $infile1 -outDir $outsnv/ -log -t $t_value -tf $tf_value
            k+=1
            print(' ')
# Out:
# /alina-data2/sai/shiver_working_dir/MIX1_S2/qtrim_20/SID.sam /alina-data2/sai/ipython_working_dir/bbduk_shiver_snvOut/MIX1_S2/qtrim_20/t_10_tf_0.034
# Start read sam
# 1215000 DONE
# Start convert
# 1133000 DONE
# Total reads number: 1407326
# read 76134
# Start 2SNV method
# Compute profile - DONE 6231
# Compute SNV data structure - DONE 38064
# Compute cliquesCommon reads matrix calculation
# 1071
# 33 127 T G m1=16 m2=105814 hits=15 pO=1.998e-15 reads=35338 18924 16343 1 15 false
# 59 127 A G m1=41230 m2=105814 hits=32442 pO=0.000e+00 reads=97387 38775 17447 8664 32442 false
# 59 173 A A m1=41230 m2=2665 hits=622 pO=0.000e+00 reads=96303 55426 122 40104 622 false
# 59 350 A G m1=41230 m2=365630 hits=18401 pO=0.000e+00 reads=62673 20850 14660 8587 18401 false
# 59 386 A G m1=41230 m2=7204 hits=299 pO=0.000e+00 reads=60238 34118 202 25592 299 false
# 59 389 A C m1=41230 m2=382592 hits=15847 pO=0.000e+00 reads=60106 20689 13509 10027 15847 false
# ...
