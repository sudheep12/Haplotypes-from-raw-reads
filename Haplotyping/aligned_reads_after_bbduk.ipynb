# %%
from Bio import SeqIO
import os

# %%
dir1= "bbduk_on_raw_reads"
mixtures_list= ["MIX1_S2","MIX2","MIX3"]
R1_files= ["R1_.fastq"]
R2_files=["R2_.fastq"]
qtrim_values= ["20", "25", "30"]
ref_fasta= "/alina-data2/sai/cdc_real_reads/cdc_real_reads/ref/ref.fas"

# %%
j=0
for i in mixtures_list:
    for j in qtrim_values:
        infiles1= os.path.abspath(os.path.join(dir1,i, "qtrim_"+ j + "R1_.fastq"))
        infiles2= os.path.abspath(os.path.join(dir1,i, "qtrim_" + j + "R2_.fastq"))
#         out= os.path.abspath(os.path.join("samfiles_of_bbduk_reads", i,"qtrim_"+ j))
        outfiles= os.path.abspath(os.path.join("samfiles_of_bbduk_reads", i, "qtrim_"+ j ))
        
        print(infiles1, infiles2,outfiles)
        # !mkdir -p $outfiles
        # !bwa mem $ref_fasta $infiles1 $infiles2 > $outfiles/aln_out.sam
# Out:
# /alina-data2/sai/ipython_working_dir/bbduk_on_raw_reads/MIX1_S2/qtrim_20R1_.fastq /alina-data2/sai/ipython_working_dir/bbduk_on_raw_reads/MIX1_S2/qtrim_20R2_.fastq /alina-data2/sai/ipython_working_dir/samfiles_of_bbduk_reads/MIX1_S2/qtrim_20
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 33224 sequences (10000424 bp)...
# [M::process] read 33224 sequences (10000424 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (1, 16611, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (322, 396, 469)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (28, 763)
# [M::mem_pestat] mean and std.dev: (403.20, 106.74)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 910)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# ...

# %%
in_dir = ["MIX1_S2/", "MIX2/", "MIX3/"]

j=0
for indata1 in in_dir:
    in_dir1 = ["qtrim_20" , "qtrim_25" ,"qtrim_30"]
#     k= in_dir1[j]
#     print(k)
    for a in in_dir1:
        in_sam= os.path.abspath(os.path.join("samfiles_of_bbduk_reads", indata1, a, "aln_out.sam"))
        clique_out = os.path.abspath(os.path.join("bbduk_CliqueSNV_output", indata1,a))
        outpath= ["t_10_tf_0.034", "t_50_tf_0.005", "t_100_tf_0.01", "t_200_tf_0.02", "t_500_tf_0.05"]
        j+=1
        i=0
        for cd in outpath:
            t = ['10', '50', '100', '200', '500']
            tf= ['0.00034','0.005', '0.01', '0.02', '0.05']
            t_value = t[i]
            tf_value = tf[i]
            outsnv= os.path.abspath(os.path.join(clique_out, cd))
            print(in_sam, outsnv)
            # !java -jar /home/code/cliquesnv/CliqueSNV/clique-snv.jar -m snv-illumina -in $in_sam -outDir $outsnv/ -log -t $t_value -tf $tf_value
            i+=1
            print(' ')
# Out:
# /alina-data2/sai/ipython_working_dir/samfiles_of_bbduk_reads/MIX1_S2/qtrim_20/aln_out.sam /alina-data2/sai/ipython_working_dir/bbduk_CliqueSNV_output/MIX1_S2/qtrim_20/t_10_tf_0.034
# Start read sam
# 1336000 DONE
# Start convert
# 1302000 DONE
# Total reads number: 1848231
# read 55880
# Start 2SNV method
# Compute profile - DONE 9821
# Compute SNV data structure - DONE 59101
# Compute cliquesCommon reads matrix calculation
# 1065
# 20 317 C C m1=857 m2=435 hits=31 pO=0.000e+00 reads=19902 19151 81 510 31 false
# 33 127 T G m1=22 m2=128404 hits=21 pO=0.000e+00 reads=43409 23337 19969 1 21 false
# 53 350 G G m1=110 m2=443508 hits=70 pO=6.539e-14 reads=49939 26498 23041 29 70 false
# 54 350 G G m1=22 m2=443508 hits=20 pO=0.000e+00 reads=58604 30113 28050 1 20 false
# 59 127 A G m1=47784 m2=128404 hits=37758 pO=0.000e+00 reads=118062 48592 21609 10012 37758 false
# 59 173 A A m1=47784 m2=3128 hits=732 pO=0.000e+00 reads=118042 70033 188 47035 732 false
# ...
